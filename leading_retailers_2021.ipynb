# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
retailers = pd.read_csv("leading_retailers_2021.csv", encoding =  "ISO-8859-1")

# %%
retailers
# Out:
#      Rank                  Name of Company         Location  \
# 0       1                     Walmart Inc     United States
# 1       2                 Amazon.com, Inc.    United States
# 2       3     Costco Wholesale Corporation    United States
# 3       4                    Schwarz Group          Germany
# 4       5              The Home Depot, Inc    United States
# ..    ...                              ...              ...
# 245   246                EG Group Limited    United Kingdom
# 246   247                 Yaoko Co., Ltd.            Japan
# 247   248       Daiso Industries Co., Ltd            Japan
# 248   249                  Shufersal Ltd.           Israel
# 249   250  T. J. Morris dba Home Bargains   United Kingdom
#
#     FY2021_retail_revenue FY2021_parent_company/ group revenue  \
# 0                5,72,754                             5,72,754
# 1                2,39,150                             4,69,822
# ...

# %%
retailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rank                                  250 non-null    int64
#  1   Name of Company                       250 non-null    object
#  2   Location                              250 non-null    object
#  3   FY2021_retail_revenue                 250 non-null    object
#  4   FY2021_parent_company/ group revenue  250 non-null    object
#  5   Dominant_operational_format           250 non-null    object
#  6   Geographies_of_operation              250 non-null    int64
#  7   FY2016- 2021_retail_revenueCAGR3      248 non-null    object
#  8   FY2020-2021_retail_revenue_growth     248 non-null    object
#  9   FY2021_Net_profit_margin              208 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 19.7+ KB

# %%
retailers.isnull().sum()
# Out:
# Rank                                     0
# Name of Company                          0
# Location                                 0
# FY2021_retail_revenue                    0
# FY2021_parent_company/ group revenue     0
# Dominant_operational_format              0
# Geographies_of_operation                 0
# FY2016- 2021_retail_revenueCAGR3         2
# FY2020-2021_retail_revenue_growth        2
# FY2021_Net_profit_margin                42
# dtype: int64

# %%
retailers.nunique()
# Out:
# Rank                                    250
# Name of Company                         250
# Location                                 73
# FY2021_retail_revenue                   246
# FY2021_parent_company/ group revenue    248
# Dominant_operational_format              26
# Geographies_of_operation                 49
# FY2016- 2021_retail_revenueCAGR3        161
# FY2020-2021_retail_revenue_growth       178
# FY2021_Net_profit_margin                107
# dtype: int64

# %%
retailers.describe()
# Out:
#              Rank  Geographies_of_operation
# count  250.000000                250.000000
# mean   125.500000                 11.400000
# std     72.312977                 22.953594
# min      1.000000                  1.000000
# 25%     63.250000                  1.000000
# 50%    125.500000                  3.000000
# 75%    187.750000                 11.000000
# max    250.000000                215.000000

# %%
retailers.Location.unique()
# Out:
# array(['United States', 'Germany', 'United States ', 'China ', 'Germany ',
#        'Netherlands ', 'United Kingdom', 'Japan ', 'Japan', 'France',
#        ' United States ', 'France  ', 'Canada', 'Australia',
#        'Hong Kong SAR ', 'United Kingdom ', 'Spain', 'Spain  ', 'France ',
#        'Russia', 'Australia ', 'Switzerland', 'Portugal ', 'Germany  ',
#        'Russia ', 'United States  ', 'Sweden', 'India  ', 'South Korea ',
#        'United Kingdom  ', 'Italy', 'Thailand ', 'China', 'Canada  ',
#        'Mexico', 'Austria', 'Finland', 'Chile ', 'Italy ', 'South Korea',
#        'Spain ', 'Chile', 'South Africa ', 'Norway ', 'Canada ',
#        'Denmark ', 'Mexico ', 'Belgium ', 'Austria  ', 'Netherlands  ',
#        'United Statese ', 'Finland ', 'Africa ', 'Taiwan (China)',
#        'Hong Kong SAR', 'Netherlands', 'United Arab Emirates ', 'Turkey',
#        'Norway', 'Sweden ', 'Brazil ', 'Indonesia', 'Austria ',
# ...

# %%
retailers.Dominant_operational_format.unique()
# Out:
# array([' Hypermarket/ supercenter ', 'Non-store',
#        'Cash & carry/ warehouse club', 'Discount store',
#        'Home improvement', 'Supermarket', 'Drug store/ pharmacy',
#        'Discount department store ', 'Hypermarket/ supercenter',
#        'Convenience/ forecourt store', 'Supermarket ',
#        ' Hypermarket/ supercenter', 'Other specialty',
#        'Electronics specialty', ' Apparel/ footwear specialty',
#        'Apparel/ footwear specialty', 'Discount stor', 'Department store',
#        ' Home improvement', ' Electronics specialty',
#        ' Cash & carry/ warehouse club', 'Discount department store',
#        ' Other specialty', ' Supermarket', ' Non-store',
#        ' Convenience/ forecourt store'], dtype=object)

# %%
retailers.rename(columns={'Name of Company': 'Name_of_Company'}, inplace=True)

# %%
retailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rank                                  250 non-null    int64
#  1   Name_of_Company                       250 non-null    object
#  2   Location                              250 non-null    object
#  3   FY2021_retail_revenue                 250 non-null    object
#  4   FY2021_parent_company/ group revenue  250 non-null    object
#  5   Dominant_operational_format           250 non-null    object
#  6   Geographies_of_operation              250 non-null    int64
#  7   FY2016- 2021_retail_revenueCAGR3      248 non-null    object
#  8   FY2020-2021_retail_revenue_growth     248 non-null    object
#  9   FY2021_Net_profit_margin              208 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 19.7+ KB

# %%
retailers.Name_of_Company.unique()
# Out:
# array(['Walmart Inc ', 'Amazon.com, Inc.', 'Costco Wholesale Corporation',
#        'Schwarz Group', 'The Home Depot, Inc', 'The Kroger Co. ',
#        'JD.com, Inc ', 'Walgreens Boots Alliance, Inc. ',
#        'Aldi Einkauf GmbH & Co. oHG and Aldi International Services GmbH & Co. oHG120,947 e  e',
#        'Target Corporation ', 'CVS Health Corporation ',
#        "Lowe's Companies, Inc. ", 'Ahold Delhaize ', 'Tesco PLC  ',
#        'Seven & i Holdings Co., Ltd. ', 'Edeka-Verbund  ',
#        'Aeon Co., Ltd.  ', 'Albertsons Companies, Inc. ', 'Rewe Group',
#        'LVMH Moët HennessyLouis Vuitton S.A.  ',
#        'Centres Distributeurs E. Leclerc   ', 'Best Buy Co., Inc.',
#        'The TJX Companies, Inc. ', 'Publix Super Markets, Inc. ',
#        'The IKEA Group (INGKA Holding B.V.) ',
#        'ITM Développement International (Intermarché) ',
#        'Loblaw Companies Limited   ', 'Woolworths Limited ',
#        'Alibaba Group Holding Limited/ New Retail & Direct Sales ',
# ...

# %%
retailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rank                                  250 non-null    int64
#  1   Name_of_Company                       250 non-null    object
#  2   Location                              250 non-null    object
#  3   FY2021_retail_revenue                 250 non-null    object
#  4   FY2021_parent_company/ group revenue  250 non-null    object
#  5   Dominant_operational_format           250 non-null    object
#  6   Geographies_of_operation              250 non-null    int64
#  7   FY2016- 2021_retail_revenueCAGR3      248 non-null    object
#  8   FY2020-2021_retail_revenue_growth     248 non-null    object
#  9   FY2021_Net_profit_margin              208 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 19.7+ KB

# %%
retailers
# Out:
#      Rank                  Name_of_Company         Location  \
# 0       1                     Walmart Inc     United States
# 1       2                 Amazon.com, Inc.    United States
# 2       3     Costco Wholesale Corporation    United States
# 3       4                    Schwarz Group          Germany
# 4       5              The Home Depot, Inc    United States
# ..    ...                              ...              ...
# 245   246                EG Group Limited    United Kingdom
# 246   247                 Yaoko Co., Ltd.            Japan
# 247   248       Daiso Industries Co., Ltd            Japan
# 248   249                  Shufersal Ltd.           Israel
# 249   250  T. J. Morris dba Home Bargains   United Kingdom
#
#     FY2021_retail_revenue FY2021_parent_company/ group revenue  \
# 0                5,72,754                             5,72,754
# 1                2,39,150                             4,69,822
# ...

# %%
#remove the comma in the column
retailers['FY2021_retail_revenue']=retailers['FY2021_retail_revenue'].str.replace(',','')

# %%
#remove the comma in the column
retailers['FY2021_parent_company/ group revenue']=retailers['FY2021_parent_company/ group revenue'].str.replace(',','')

# %%
#test
retailers
# Out:
#      Rank                  Name_of_Company         Location  \
# 0       1                     Walmart Inc     United States
# 1       2                 Amazon.com, Inc.    United States
# 2       3     Costco Wholesale Corporation    United States
# 3       4                    Schwarz Group          Germany
# 4       5              The Home Depot, Inc    United States
# ..    ...                              ...              ...
# 245   246                EG Group Limited    United Kingdom
# 246   247                 Yaoko Co., Ltd.            Japan
# 247   248       Daiso Industries Co., Ltd            Japan
# 248   249                  Shufersal Ltd.           Israel
# 249   250  T. J. Morris dba Home Bargains   United Kingdom
#
#     FY2021_retail_revenue FY2021_parent_company/ group revenue  \
# 0                  572754                               572754
# 1                  239150                               469822
# ...

# %%
#covert the column to integer
retailers[['FY2021_retail_revenue']] = retailers[['FY2021_retail_revenue']].astype(int)

# %%
retailers['FY2021_parent_company/ group revenue'] = retailers['FY2021_parent_company/ group revenue'].astype(int)

# %%
#test
retailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rank                                  250 non-null    int64
#  1   Name_of_Company                       250 non-null    object
#  2   Location                              250 non-null    object
#  3   FY2021_retail_revenue                 250 non-null    int32
#  4   FY2021_parent_company/ group revenue  250 non-null    int32
#  5   Dominant_operational_format           250 non-null    object
#  6   Geographies_of_operation              250 non-null    int64
#  7   FY2016- 2021_retail_revenueCAGR3      248 non-null    object
#  8   FY2020-2021_retail_revenue_growth     248 non-null    object
#  9   FY2021_Net_profit_margin              208 non-null    object
# dtypes: int32(2), int64(2), object(6)
# memory usage: 17.7+ KB

# %%
#remove the % in the column 
retailers['FY2016- 2021_retail_revenueCAGR3']=retailers['FY2016- 2021_retail_revenueCAGR3'].str.replace('%','')

# %%
retailers
# Out:
#      Rank                  Name_of_Company         Location  \
# 0       1                     Walmart Inc     United States
# 1       2                 Amazon.com, Inc.    United States
# 2       3     Costco Wholesale Corporation    United States
# 3       4                    Schwarz Group          Germany
# 4       5              The Home Depot, Inc    United States
# ..    ...                              ...              ...
# 245   246                EG Group Limited    United Kingdom
# 246   247                 Yaoko Co., Ltd.            Japan
# 247   248       Daiso Industries Co., Ltd            Japan
# 248   249                  Shufersal Ltd.           Israel
# 249   250  T. J. Morris dba Home Bargains   United Kingdom
#
#      FY2021_retail_revenue  FY2021_parent_company/ group revenue  \
# 0                   572754                                572754
# 1                   239150                                469822
# ...

# %%
#remove % in these columns also
retailers['FY2020-2021_retail_revenue_growth']=retailers['FY2020-2021_retail_revenue_growth'].str.replace('%','')
retailers['FY2021_Net_profit_margin']=retailers['FY2021_Net_profit_margin'].str.replace('%','')

# %%
retailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rank                                  250 non-null    int64
#  1   Name_of_Company                       250 non-null    object
#  2   Location                              250 non-null    object
#  3   FY2021_retail_revenue                 250 non-null    int32
#  4   FY2021_parent_company/ group revenue  250 non-null    int32
#  5   Dominant_operational_format           250 non-null    object
#  6   Geographies_of_operation              250 non-null    int64
#  7   FY2016- 2021_retail_revenueCAGR3      248 non-null    object
#  8   FY2020-2021_retail_revenue_growth     248 non-null    object
#  9   FY2021_Net_profit_margin              208 non-null    object
# dtypes: int32(2), int64(2), object(6)
# memory usage: 17.7+ KB

# %%
#fill the NaN values with null
retailers['FY2016- 2021_retail_revenueCAGR3']=retailers['FY2016- 2021_retail_revenueCAGR3'].fillna('null')

# %%
retailers['FY2021_Net_profit_margin']=retailers['FY2021_Net_profit_margin'].fillna('null')

# %%
retailers['FY2020-2021_retail_revenue_growth']=retailers['FY2020-2021_retail_revenue_growth'].fillna('null')

# %%
#Test
retailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rank                                  250 non-null    int64
#  1   Name_of_Company                       250 non-null    object
#  2   Location                              250 non-null    object
#  3   FY2021_retail_revenue                 250 non-null    int32
#  4   FY2021_parent_company/ group revenue  250 non-null    int32
#  5   Dominant_operational_format           250 non-null    object
#  6   Geographies_of_operation              250 non-null    int64
#  7   FY2016- 2021_retail_revenueCAGR3      250 non-null    object
#  8   FY2020-2021_retail_revenue_growth     250 non-null    object
#  9   FY2021_Net_profit_margin              250 non-null    object
# dtypes: int32(2), int64(2), object(6)
# memory usage: 17.7+ KB

# %%
#replace null with nan
retailers['FY2021_Net_profit_margin'] = retailers['FY2021_Net_profit_margin'].replace('null', np.nan)

# %%
#replace n/a with nan
retailers['FY2021_Net_profit_margin'] = retailers['FY2021_Net_profit_margin'].replace(' n/a', np.nan)

# %%
retailers['FY2021_Net_profit_margin']=retailers['FY2021_Net_profit_margin'].astype(float)

# %%
#test
retailers
# Out:
#      Rank                  Name_of_Company         Location  \
# 0       1                     Walmart Inc     United States
# 1       2                 Amazon.com, Inc.    United States
# 2       3     Costco Wholesale Corporation    United States
# 3       4                    Schwarz Group          Germany
# 4       5              The Home Depot, Inc    United States
# ..    ...                              ...              ...
# 245   246                EG Group Limited    United Kingdom
# 246   247                 Yaoko Co., Ltd.            Japan
# 247   248       Daiso Industries Co., Ltd            Japan
# 248   249                  Shufersal Ltd.           Israel
# 249   250  T. J. Morris dba Home Bargains   United Kingdom
#
#      FY2021_retail_revenue  FY2021_parent_company/ group revenue  \
# 0                   572754                                572754
# 1                   239150                                469822
# ...

# %%
#replace n/a with nan
retailers['FY2016- 2021_retail_revenueCAGR3'] = retailers['FY2016- 2021_retail_revenueCAGR3'].replace(' n/a', np.nan)

# %%
retailers['FY2016- 2021_retail_revenueCAGR3'] = retailers['FY2016- 2021_retail_revenueCAGR3'].replace(' null', np.nan)

# %%
retailers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rank                                  250 non-null    int64
#  1   Name_of_Company                       250 non-null    object
#  2   Location                              250 non-null    object
#  3   FY2021_retail_revenue                 250 non-null    int32
#  4   FY2021_parent_company/ group revenue  250 non-null    int32
#  5   Dominant_operational_format           250 non-null    object
#  6   Geographies_of_operation              250 non-null    int64
#  7   FY2016- 2021_retail_revenueCAGR3      249 non-null    object
#  8   FY2020-2021_retail_revenue_growth     250 non-null    object
#  9   FY2021_Net_profit_margin              190 non-null    float64
# dtypes: float64(1), int32(2), int64(2), object(5)
# memory usage: 17.7+ KB

# %%
retailers['Dominant_operational_format'] = retailers['Dominant_operational_format'].str.strip()

# %%
retailers['Dominant_operational_format'] = retailers['Dominant_operational_format'].replace({'Discount stor' : 'Discount department store'})

# %%
#find the dominant operational format of these stores that is most popular
dominant_stores=retailers['Dominant_operational_format'].value_counts()
dominant_stores
# Out:
# Supermarket                     58
# Other specialty                 39
# Hypermarket/ supercenter        26
# Discount store                  19
# Apparel/ footwear specialty     19
# Electronics specialty           16
# Department store                16
# Home improvement                13
# Convenience/ forecourt store    13
# Drug store/ pharmacy            12
# Non-store                       11
# Discount department store        5
# Cash & carry/ warehouse club     3
# Name: Dominant_operational_format, dtype: int64

# %%
#create a graph of the data
plt.figure(figsize=(15,9))
dominant_stores.plot.bar(x='Dominant_operational_format', y = 'dominant_stores',title='Leading Operational Format');

# %%
retailers['Location'] =retailers['Location'].str.strip()

# %%
retailers['Location'] = retailers['Location'].replace({'United Statese' : 'United States'})
retailers['Location'].value_counts()
# Out:
# United States           71
# Japan                   27
# United Kingdom          19
# Germany                 17
# France                  12
# China                    9
# Canada                   8
# South Korea              6
# Spain                    5
# Russia                   5
# Mexico                   5
# Australia                5
# Hong Kong SAR            4
# Brazil                   4
# Italy                    4
# South Africa             4
# Netherlands              4
# Austria                  3
# Switzerland              3
# Norway                   3
# Denmark                  3
# Sweden                   3
# Finland                  2
# Taiwan (China)           2
# Indonesia                2
# Portugal                 2
# Chile                    2
# United Arab Emirates     2
# Turkey                   2
# Belgium                  2
# Thailand                 2
# Africa                   1
# India                    1
# Philippines              1
# ...

# %%
#find the country with the most stores
countries = retailers['Location'].value_counts().nlargest(10)
countries
# Out:
# United States     71
# Japan             27
# United Kingdom    19
# Germany           17
# France            12
# China              9
# Canada             8
# South Korea        6
# Spain              5
# Russia             5
# Name: Location, dtype: int64

# %%
#represent the dat in a graph
plt.figure
countries.plot.bar(x='Location', y='countries',color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Top Ten Countries');

# %%
retailers
# Out:
#      Rank                  Name_of_Company         Location  \
# 0       1                     Walmart Inc     United States
# 1       2                 Amazon.com, Inc.    United States
# 2       3     Costco Wholesale Corporation    United States
# 3       4                    Schwarz Group          Germany
# 4       5              The Home Depot, Inc    United States
# ..    ...                              ...              ...
# 245   246                EG Group Limited    United Kingdom
# 246   247                 Yaoko Co., Ltd.            Japan
# 247   248       Daiso Industries Co., Ltd            Japan
# 248   249                  Shufersal Ltd.           Israel
# 249   250  T. J. Morris dba Home Bargains   United Kingdom
#
#      FY2021_retail_revenue  FY2021_parent_company/ group revenue  \
# 0                   572754                                572754
# 1                   239150                                469822
# ...

# %%
top_ten=retailers.nlargest(10, 'FY2021_Net_profit_margin')[['FY2021_Net_profit_margin','Name_of_Company', 'Location']]
top_ten
# Out:
#      FY2021_Net_profit_margin                         Name_of_Company  \
# 209                      34.6      Liquor Control Board of Ontario
# 119                      27.3               Hermès International SCA
# 19                       19.8  LVMH Moët HennessyLouis Vuitton S.A.
# 68                       18.5                             Kering S.A.
# 150                      16.9                Bath & Body Works, Inc.
# 91                       16.2              O'Reilly Automotive, Inc.
# 195                      15.6               lululemon athletica inc.
# 80                       14.8                          AutoZone, Inc.
# 203                      14.6                               Next plc
# 138                      13.7                  Williams-Sonoma, Inc.
#
#              Location
# 209           Canada
# 119            France
# 19             France
# 68            France
# 150    United States
# 91     United States
# 195           Canada
# 80     United States
# ...

# %%
#check the styles availabe
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#plot the data
plt.figure(figsize=(15,15))
top_ten.plot.bar(x='Name_of_Company', y='FY2021_Net_profit_margin', color='tab:cyan')
plt.xticks(rotation=90, ha='right')
plt.xlabel('Company', fontsize=14, fontweight='bold')
plt.ylabel('Net Profit Margin in %', fontsize=14, fontweight='bold')
plt.title('Companies With Highest Profit Margin in 2021', fontsize=16);

# %%
retailers
# Out:
#      Rank                  Name_of_Company         Location  \
# 0       1                     Walmart Inc     United States
# 1       2                 Amazon.com, Inc.    United States
# 2       3     Costco Wholesale Corporation    United States
# 3       4                    Schwarz Group          Germany
# 4       5              The Home Depot, Inc    United States
# ..    ...                              ...              ...
# 245   246                EG Group Limited    United Kingdom
# 246   247                 Yaoko Co., Ltd.            Japan
# 247   248       Daiso Industries Co., Ltd            Japan
# 248   249                  Shufersal Ltd.           Israel
# 249   250  T. J. Morris dba Home Bargains   United Kingdom
#
#      FY2021_retail_revenue  FY2021_parent_company/ group revenue  \
# 0                   572754                                572754
# 1                   239150                                469822
# ...

# %%
retailers.Geographies_of_operation
# Out:
# 0      24
# 1      21
# 2      12
# 3      33
# 4       3
#        ..
# 245    10
# 246     1
# 247    26
# 248     1
# 249     1
# Name: Geographies_of_operation, Length: 250, dtype: int64

# %%
geographies = retailers.nlargest(10,'Geographies_of_operation')[['Name_of_Company','Location','Geographies_of_operation']]
geographies
# Out:
#                             Name_of_Company        Location  \
# 34                          Inditex, S.A.             Spain
# 206                         Tapestry, Inc.    United States
# 160                Natura & Co Holding S.A          Brazil
# 79                  Marks and Spencer Group  United Kingdom
# 68                              Kering S.A.         France
# 19   LVMH Moët HennessyLouis Vuitton S.A.            France
# 51              H & M Hennes & Mauritz AB            Sweden
# 58                NIKE, Inc. / NIKE Direct   United States
# 172                Victoria's Secret & Co.   United States
# 74                          Décathlon S.A.         France
#
#      Geographies_of_operation
# 34                        215
# 206                       125
# 160                       100
# 79                         98
# 68                         95
# 19                         80
# 51                         75
# 58                         74
# ...

# %%
#plot the data
sns.set_style('darkgrid')
plt.figure(figsize=(12,9))
ax = sns.barplot(x="Name_of_Company", y="Geographies_of_operation", data=geographies,dodge = False,palette='Paired', hue="Location")
ax.set(xlabel='Company', ylabel='Geographies of Operation', title='Top 10 Companies by Geographies of Operation')
plt.xticks(rotation=45, ha='right');

# %%
net_profit_by_format = retailers.groupby('Dominant_operational_format')['FY2021_Net_profit_margin'].mean().sort_values(ascending=False)
net_profit_by_format=net_profit_by_format.reset_index()

# %%
sns.pointplot(data=net_profit_by_format , x='Dominant_operational_format' , y='FY2021_Net_profit_margin')
plt.xticks(rotation=90)
plt.show()
